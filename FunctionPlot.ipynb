# %% [markdown]
# #### Funkcja o dwóch zmiennych, to z graficznego punktu widzenia wykres przestawiony w trójwymiarze. Funkcja o dwóch zmiennych zawiera w sobie dwie zmienne f(x, y) - w tym przypadku te zmienne to 'x' i 'y'.

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Ustalenie funkcji. W tym przypadku:
# ### f(x,y) = - x^2 - y^2

# %%
def f(x, y):
    return - x**2 - y**2

# %% [markdown]
# Ustalenie zakresu obliczeń.

# %%
x = np.linspace(-4, 4, 10)
y = np.linspace(-4, 4, 10)

# %%
X, Y = np.meshgrid(x, y)

# %%
Z = f(X,Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,cmap='jet', edgecolor = 'none')

# %% [markdown]
# # Ustalenie funkcji. W tym przypadku:
# ### f(x,y) = x^2 + 2xy^2

# %%
def f(x, y):
    return x**2 + 2 * x * y**2

# %%
x = np.linspace(-4, 4, 10)
y = np.linspace(-4, 4, 10)

# %%
X, Y = np.meshgrid(x, y)

Z = f(X,Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,cmap='jet', edgecolor = 'none')

# %%
def f(x, y):
    return x ** 2 + 3 * y ** 2

# %%
x = np.linspace(-4, 4, 10)
y = np.linspace(-4, 4, 10)

# %%
X, Y = np.meshgrid(x, y)

Z = f(X,Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,cmap='jet', edgecolor = 'black')
